# %% [markdown]
# # Implementación de Hough Base

# %%
# !nvidia-smi
# Out:
# Fri Nov 24 19:57:41 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
# !nvcc -o houghBase houghBase.cu common/pgm.cpp

# %%
# !./houghBase runway.pgm
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Calculation mismatch at : 3535 3005 0
# Calculation mismatch at : 3536 3148 0
# Calculation mismatch at : 3537 3199 0
# Calculation mismatch at : 3538 3399 0
# Calculation mismatch at : 3539 3577 0
# Calculation mismatch at : 3540 3698 0
# Calculation mismatch at : 3541 4026 0
# Calculation mismatch at : 3542 3912 0
# Calculation mismatch at : 3543 3935 0
# Calculation mismatch at : 3544 3517 0
# Calculation mismatch at : 3545 3111 0
# Calculation mismatch at : 3546 3006 0
# Calculation mismatch at : 3547 2940 0
# Calculation mismatch at : 3548 2909 0
# Calculation mismatch at : 3549 3180 0
# Calculation mismatch at : 3550 3233 0
# Calculation mismatch at : 3551 3309 0
# Calculation mismatch at : 3552 3383 0
# Calculation mismatch at : 3553 3557 0
# Calculation mismatch at : 3554 3612 0
# Calculation mismatch at : 3555 3827 0
# Calculation mismatch at : 3556 3753 0
# Calculation mismatch at : 3557 3699 0
# ...

# %% [markdown]
# # Implementacion de houg con memoria Global

# %%
# !nvcc -o houghGlobal houghGlobal.cu common/pgm.cpp

# %%
# !./houghGlobal runway.pgm
# Out:
# Calculation mismatch at : 1803 1446 1445
# Calculation mismatch at : 1893 1506 1507
# Calculation mismatch at : 5931 1653 1654
# Calculation mismatch at : 6021 1816 1815
# Calculation mismatch at : 6104 1642 1641
# Calculation mismatch at : 6194 1586 1587
